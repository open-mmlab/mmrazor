# %% [markdown]
# # 使用MMRazor对ResNet34进行剪枝

# %% [markdown]
# 本教程主要介绍如何手动配置剪枝config。此外外我们还提供一种自动获取剪枝config的方式，请参考 [Search and prune/准备剪枝Config](./search_and_prune.ipynb#prune_config)

# %% [markdown]
# ## 回顾MMCls

# %%
# Prepare config path
MMCLS_PATH='/home/liukai/Documents/mmlab2/others/mmclassification/'
config_file=MMCLS_PATH+'configs/resnet/resnet34_8xb32_in1k.py'

# %%
# Run config
# !python ./tools/train.py $config_file

# %% [markdown]
# ## 准备剪枝config

# %% [markdown]
# 1. 跨库调用resnet34配置文件
# 2. 增加pretrained参数
# 3. 将resnet34模型装入剪枝算法wrapper中
# 4. 配置剪枝比例
# 5. 运行

# %%
from mmengine import Config
prune_config_path='./prune_resnet34.py'
def write_config(config_str,filename):
    with open(filename,'w') as f:
        f.write(config_str)

# %% [markdown]
# ### 1. 跨库调用resnet34配置文件
#
# 首先我们先跨库调用resnet34的配置文件。通过跨库调用，我们可以继承原有配置文件的所有内容。

# %%
config_string = """
_base_ = ['mmcls::resnet/resnet34_8xb32_in1k.py']
"""
write_config(config_string, prune_config_path)
print(Config.fromfile(prune_config_path)['model'])
# Out:
# {'type': 'ImageClassifier', 'backbone': {'type': 'ResNet', 'depth': 34, 'num_stages': 4, 'out_indices': (3,), 'style': 'pytorch'}, 'neck': {'type': 'GlobalAveragePooling'}, 'head': {'type': 'LinearClsHead', 'num_classes': 1000, 'in_channels': 512, 'loss': {'type': 'CrossEntropyLoss', 'loss_weight': 1.0}, 'topk': (1, 5)}, '_scope_': 'mmcls'}
# /home/liukai/Documents/mmlab2/others/max/mmengine/mmengine/config/utils.py:50: UserWarning: There is not `Config` define in {'Name': 'convnext-base_3rdparty_in21k', 'Metadata': {'Training Data': 'ImageNet-21k', 'FLOPs': 15359124480, 'Parameters': 88591464}, 'In Collection': 'ConvNeXt', 'Results': None, 'Weights': 'https://download.openmmlab.com/mmclassification/v0/convnext/convnext-base_3rdparty_in21k_20220124-13b83eec.pth', 'Converted From': {'Weights': 'https://dl.fbaipublicfiles.com/convnext/convnext_base_22k_224.pth', 'Code': 'https://github.com/facebookresearch/ConvNeXt'}}
#   warnings.warn(f'There is not `Config` define in {model_cfg}')
# /home/liukai/Documents/mmlab2/others/max/mmengine/mmengine/config/utils.py:50: UserWarning: There is not `Config` define in {'Name': 'convnext-large_3rdparty_in21k', 'Metadata': {'Training Data': 'ImageNet-21k', 'FLOPs': 34368026112, 'Parameters': 197767336}, 'In Collection': 'ConvNeXt', 'Results': None, 'Weights': 'https://download.openmmlab.com/mmclassification/v0/convnext/convnext-large_3rdparty_in21k_20220124-41b5a79f.pth', 'Converted From': {'Weights': 'https://dl.fbaipublicfiles.com/convnext/convnext_large_22k_224.pth', 'Code': 'https://github.com/facebookresearch/ConvNeXt'}}
#   warnings.warn(f'There is not `Config` define in {model_cfg}')
# /home/liukai/Documents/mmlab2/others/max/mmengine/mmengine/config/utils.py:50: UserWarning: There is not `Config` define in {'Name': 'convnext-xlarge_3rdparty_in21k', 'Metadata': {'Training Data': 'ImageNet-21k', 'FLOPs': 60929820672, 'Parameters': 350196968}, 'In Collection': 'ConvNeXt', 'Results': None, 'Weights': 'https://download.openmmlab.com/mmclassification/v0/convnext/convnext-xlarge_3rdparty_in21k_20220124-f909bad7.pth', 'Converted From': {'Weights': 'https://dl.fbaipublicfiles.com/convnext/convnext_xlarge_22k_224.pth', 'Code': 'https://github.com/facebookresearch/ConvNeXt'}}
#   warnings.warn(f'There is not `Config` define in {model_cfg}')
# /home/liukai/Documents/mmlab2/others/max/mmengine/mmengine/config/utils.py:50: UserWarning: There is not `Config` define in {'Name': 'swinv2-base-w12_3rdparty_in21k-192px', 'Metadata': {'Training Data': 'ImageNet-21k', 'FLOPs': 8510000000, 'Parameters': 87920000}, 'In Collection': 'Swin-Transformer V2', 'Results': None, 'Weights': 'https://download.openmmlab.com/mmclassification/v0/swin-v2/pretrain/swinv2-base-w12_3rdparty_in21k-192px_20220803-f7dc9763.pth', 'Converted From': {'Weights': 'https://github.com/SwinTransformer/storage/releases/download/v2.0.0/swinv2_base_patch4_window12_192_22k.pth', 'Code': 'https://github.com/microsoft/Swin-Transformer'}}
#   warnings.warn(f'There is not `Config` define in {model_cfg}')
# /home/liukai/Documents/mmlab2/others/max/mmengine/mmengine/config/utils.py:50: UserWarning: There is not `Config` define in {'Name': 'swinv2-large-w12_3rdparty_in21k-192px', 'Metadata': {'Training Data': 'ImageNet-21k', 'FLOPs': 19040000000, 'Parameters': 196740000}, 'In Collection': 'Swin-Transformer V2', 'Results': None, 'Weights': 'https://download.openmmlab.com/mmclassification/v0/swin-v2/pretrain/swinv2-large-w12_3rdparty_in21k-192px_20220803-d9073fee.pth', 'Converted From': {'Weights': 'https://github.com/SwinTransformer/storage/releases/download/v2.0.0/swinv2_large_patch4_window12_192_22k.pth', 'Code': 'https://github.com/microsoft/Swin-Transformer'}}
#   warnings.warn(f'There is not `Config` define in {model_cfg}')

# %% [markdown]
# ### 2. 增加预训练参数
# 我们将原有的’model‘字段取出，命名为architecture，并且给archtecture增加init_cfg字段用来加载预训练模型参数。

# %%
config_string += """\n
data_preprocessor = {'type': 'mmcls.ClsDataPreprocessor'}
architecture = _base_.model
architecture.update({
    'init_cfg': {
        'type':
        'Pretrained',
        'checkpoint':
        'https://download.openmmlab.com/mmclassification/v0/resnet/resnet34_8xb32_in1k_20210831-f257d4e6.pth'  # noqa
    }
})
"""
write_config(config_string, prune_config_path)

# %% [markdown]
# ### 3. 将resnet34模型装入剪枝算法wrapper中
#
# 我们将原有的model作为architecture放入到ItePruneAlgorithm算法中，并且将ItePruneAlgorithm作为新的model字段。

# %%
config_string+="""
target_pruning_ratio={}
model = dict(
    _delete_=True,
    _scope_='mmrazor',
    type='ItePruneAlgorithm',
    architecture=architecture,
    mutator_cfg=dict(
        type='ChannelMutator',
        channel_unit_cfg=dict(
            type='L1MutableChannelUnit',
            default_args=dict(choice_mode='ratio'))),
    target_pruning_ratio=target_pruning_ratio,
    step_epoch=1,
    prune_times=1,
)
"""
write_config(config_string, prune_config_path)

# %% [markdown]
# 配置到这一步时，我们的config文件已经能够运行了。但是因为我们没有配置target_pruning_ratio，因此现在跑起来就和直接用原有config跑起来没有区别，接下来我们会介绍如何配置剪枝比例

# %%
#! python ./tools/train.py $prune_config_path

# %% [markdown]
# ### 4. 配置剪枝比例

# %% [markdown]
# 我们的模型使用tracer解析模型，进而获得剪枝节点，为了方便用户配置剪枝节点比例，我们提供了一个获得剪枝节点剪枝比例配置的工具。通过该工具，我们可以方便地对剪枝比例进行配置。

# %%
! python ./tools/get_channel_units.py $prune_config_path --choice -o prune_ratio_templace.json &> /dev/null 2>&1
! cat prune_ratio_templace.json
! rm prune_ratio_templace.json
# Out:
# {
#     "backbone.conv1_(0, 64)_64":1.0,
#     "backbone.layer1.0.conv1_(0, 64)_64":1.0,
#     "backbone.layer1.1.conv1_(0, 64)_64":1.0,
#     "backbone.layer1.2.conv1_(0, 64)_64":1.0,
#     "backbone.layer2.0.conv1_(0, 128)_128":1.0,
#     "backbone.layer2.0.conv2_(0, 128)_128":1.0,
#     "backbone.layer2.1.conv1_(0, 128)_128":1.0,
#     "backbone.layer2.2.conv1_(0, 128)_128":1.0,
#     "backbone.layer2.3.conv1_(0, 128)_128":1.0,
#     "backbone.layer3.0.conv1_(0, 256)_256":1.0,
#     "backbone.layer3.0.conv2_(0, 256)_256":1.0,
#     "backbone.layer3.1.conv1_(0, 256)_256":1.0,
#     "backbone.layer3.2.conv1_(0, 256)_256":1.0,
#     "backbone.layer3.3.conv1_(0, 256)_256":1.0,
#     "backbone.layer3.4.conv1_(0, 256)_256":1.0,
#     "backbone.layer3.5.conv1_(0, 256)_256":1.0,
#     "backbone.layer4.0.conv1_(0, 512)_512":1.0,
#     "backbone.layer4.0.conv2_(0, 512)_512":1.0,
#     "backbone.layer4.1.conv1_(0, 512)_512":1.0,
#     "backbone.layer4.2.conv1_(0, 512)_512":1.0
# }

# %% [markdown]
# 我们修改该配置模板如下，并且将替换到我们的剪枝配置文件中。
#
# （该配置来源于：Li, Hao, et al. "Pruning filters for efficient convnets." arXiv preprint arXiv:1608.08710 (2016).）

# %%
target_config = """
stage_ratio_1 = 0.7
stage_ratio_2 = 0.7
stage_ratio_3 = 0.7
stage_ratio_4 = 1.0

target_pruning_ratio = {
    "backbone.conv1_(0, 64)_64": stage_ratio_1,
    "backbone.layer1.0.conv1_(0, 64)_64": stage_ratio_1,
    "backbone.layer1.1.conv1_(0, 64)_64": stage_ratio_1,
    "backbone.layer1.2.conv1_(0, 64)_64": stage_ratio_1,
    "backbone.layer2.0.conv1_(0, 128)_128": stage_ratio_2,
    "backbone.layer2.0.conv2_(0, 128)_128": stage_ratio_2,
    "backbone.layer2.1.conv1_(0, 128)_128": stage_ratio_2,
    "backbone.layer2.2.conv1_(0, 128)_128": stage_ratio_2,
    "backbone.layer2.3.conv1_(0, 128)_128": stage_ratio_2,
    "backbone.layer3.0.conv1_(0, 256)_256": stage_ratio_3,
    "backbone.layer3.0.conv2_(0, 256)_256": stage_ratio_3,
    "backbone.layer3.1.conv1_(0, 256)_256": stage_ratio_3,
    "backbone.layer3.2.conv1_(0, 256)_256": stage_ratio_3,
    "backbone.layer3.3.conv1_(0, 256)_256": stage_ratio_3,
    "backbone.layer3.4.conv1_(0, 256)_256": stage_ratio_3,
    "backbone.layer3.5.conv1_(0, 256)_256": stage_ratio_3,
    "backbone.layer4.0.conv1_(0, 512)_512": stage_ratio_4,
    "backbone.layer4.0.conv2_(0, 512)_512": stage_ratio_4,
    "backbone.layer4.1.conv1_(0, 512)_512": stage_ratio_4,
    "backbone.layer4.2.conv1_(0, 512)_512": stage_ratio_4
}
"""

# %%
config_string=config_string.replace('target_pruning_ratio={}',target_config)
write_config(config_string,prune_config_path)
! cat $prune_config_path
# Out:
# _base_ = ['mmcls::resnet/resnet34_8xb32_in1k.py']
#
#
# data_preprocessor = {'type': 'mmcls.ClsDataPreprocessor'}
# architecture = _base_.model
# architecture.update({
#     'init_cfg': {
#         'type':
#         'Pretrained',
#         'checkpoint':
#         'https://download.openmmlab.com/mmclassification/v0/resnet/resnet34_8xb32_in1k_20210831-f257d4e6.pth'  # noqa
#     }
# })
#
#
# stage_ratio_1 = 0.7
# stage_ratio_2 = 0.7
# stage_ratio_3 = 0.7
# stage_ratio_4 = 1.0
#
# target_pruning_ratio = {
#     "backbone.conv1_(0, 64)_64": stage_ratio_1,
#     "backbone.layer1.0.conv1_(0, 64)_64": stage_ratio_1,
#     "backbone.layer1.1.conv1_(0, 64)_64": stage_ratio_1,
#     "backbone.layer1.2.conv1_(0, 64)_64": stage_ratio_1,
#     "backbone.layer2.0.conv1_(0, 128)_128": stage_ratio_2,
#     "backbone.layer2.0.conv2_(0, 128)_128": stage_ratio_2,
#     "backbone.layer2.1.conv1_(0, 128)_128": stage_ratio_2,
#     "backbone.layer2.2.conv1_(0, 128)_128": stage_ratio_2,
#     "backbone.layer2.3.conv1_(0, 128)_128": stage_ratio_2,
#     "backbone.layer3.0.conv1_(0, 256)_256": stage_ratio_3,
#     "backbone.layer3.0.conv2_(0, 256)_256": stage_ratio_3,
#     "backbone.layer3.1.conv1_(0, 256)_256": stage_ratio_3,
#     "backbone.layer3.2.conv1_(0, 256)_256": stage_ratio_3,
#     "backbone.layer3.3.conv1_(0, 256)_256": stage_ratio_3,
#     "backbone.layer3.4.conv1_(0, 256)_256": stage_ratio_3,
#     "backbone.layer3.5.conv1_(0, 256)_256": stage_ratio_3,
#     "backbone.layer4.0.conv1_(0, 512)_512": stage_ratio_4,
#     "backbone.layer4.0.conv2_(0, 512)_512": stage_ratio_4,
#     "backbone.layer4.1.conv1_(0, 512)_512": stage_ratio_4,
#     "backbone.layer4.2.conv1_(0, 512)_512": stage_ratio_4
# }
#
# model = dict(
#     _delete_=True,
#     _scope_='mmrazor',
#     type='ItePruneAlgorithm',
#     architecture=architecture,
#     mutator_cfg=dict(
#         type='ChannelMutator',
#         channel_unit_cfg=dict(
#             type='L1MutableChannelUnit',
#             default_args=dict(choice_mode='ratio'))),
#     target_pruning_ratio=target_pruning_ratio,
#     step_epoch=1,
#     prune_times=1,
# )

# %% [markdown]
# ### 5. 运行

# %%
! python ./tools/train.py $prune_config_path
# Out:
# /home/liukai/Documents/mmlab2/others/max/mmengine/mmengine/config/utils.py:50: UserWarning: There is not `Config` define in {'Name': 'convnext-base_3rdparty_in21k', 'Metadata': {'Training Data': 'ImageNet-21k', 'FLOPs': 15359124480, 'Parameters': 88591464}, 'In Collection': 'ConvNeXt', 'Results': None, 'Weights': 'https://download.openmmlab.com/mmclassification/v0/convnext/convnext-base_3rdparty_in21k_20220124-13b83eec.pth', 'Converted From': {'Weights': 'https://dl.fbaipublicfiles.com/convnext/convnext_base_22k_224.pth', 'Code': 'https://github.com/facebookresearch/ConvNeXt'}}
#   warnings.warn(f'There is not `Config` define in {model_cfg}')
# /home/liukai/Documents/mmlab2/others/max/mmengine/mmengine/config/utils.py:50: UserWarning: There is not `Config` define in {'Name': 'convnext-large_3rdparty_in21k', 'Metadata': {'Training Data': 'ImageNet-21k', 'FLOPs': 34368026112, 'Parameters': 197767336}, 'In Collection': 'ConvNeXt', 'Results': None, 'Weights': 'https://download.openmmlab.com/mmclassification/v0/convnext/convnext-large_3rdparty_in21k_20220124-41b5a79f.pth', 'Converted From': {'Weights': 'https://dl.fbaipublicfiles.com/convnext/convnext_large_22k_224.pth', 'Code': 'https://github.com/facebookresearch/ConvNeXt'}}
#   warnings.warn(f'There is not `Config` define in {model_cfg}')
# /home/liukai/Documents/mmlab2/others/max/mmengine/mmengine/config/utils.py:50: UserWarning: There is not `Config` define in {'Name': 'convnext-xlarge_3rdparty_in21k', 'Metadata': {'Training Data': 'ImageNet-21k', 'FLOPs': 60929820672, 'Parameters': 350196968}, 'In Collection': 'ConvNeXt', 'Results': None, 'Weights': 'https://download.openmmlab.com/mmclassification/v0/convnext/convnext-xlarge_3rdparty_in21k_20220124-f909bad7.pth', 'Converted From': {'Weights': 'https://dl.fbaipublicfiles.com/convnext/convnext_xlarge_22k_224.pth', 'Code': 'https://github.com/facebookresearch/ConvNeXt'}}
#   warnings.warn(f'There is not `Config` define in {model_cfg}')
# /home/liukai/Documents/mmlab2/others/max/mmengine/mmengine/config/utils.py:50: UserWarning: There is not `Config` define in {'Name': 'swinv2-base-w12_3rdparty_in21k-192px', 'Metadata': {'Training Data': 'ImageNet-21k', 'FLOPs': 8510000000, 'Parameters': 87920000}, 'In Collection': 'Swin-Transformer V2', 'Results': None, 'Weights': 'https://download.openmmlab.com/mmclassification/v0/swin-v2/pretrain/swinv2-base-w12_3rdparty_in21k-192px_20220803-f7dc9763.pth', 'Converted From': {'Weights': 'https://github.com/SwinTransformer/storage/releases/download/v2.0.0/swinv2_base_patch4_window12_192_22k.pth', 'Code': 'https://github.com/microsoft/Swin-Transformer'}}
#   warnings.warn(f'There is not `Config` define in {model_cfg}')
# /home/liukai/Documents/mmlab2/others/max/mmengine/mmengine/config/utils.py:50: UserWarning: There is not `Config` define in {'Name': 'swinv2-large-w12_3rdparty_in21k-192px', 'Metadata': {'Training Data': 'ImageNet-21k', 'FLOPs': 19040000000, 'Parameters': 196740000}, 'In Collection': 'Swin-Transformer V2', 'Results': None, 'Weights': 'https://download.openmmlab.com/mmclassification/v0/swin-v2/pretrain/swinv2-large-w12_3rdparty_in21k-192px_20220803-d9073fee.pth', 'Converted From': {'Weights': 'https://github.com/SwinTransformer/storage/releases/download/v2.0.0/swinv2_large_patch4_window12_192_22k.pth', 'Code': 'https://github.com/microsoft/Swin-Transformer'}}
#   warnings.warn(f'There is not `Config` define in {model_cfg}')
# 11/02 17:45:20 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.9.13 (main, Aug 25 2022, 23:26:10) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 961503846
#     GPU 0: NVIDIA GeForce GTX 1660 Ti
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.3, V11.3.58
#     GCC: gcc (Ubuntu 11.2.0-19ubuntu1) 11.2.0
#     PyTorch: 1.12.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.3
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.3.2  (built against CUDA 11.5)
#   - Magma 2.5.2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.3, CUDNN_VERSION=8.3.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.12.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=OFF, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.13.1+cu113
#     OpenCV: 4.6.0
#     MMEngine: 0.1.0
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: None
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 11/02 17:45:21 - mmengine - INFO - Config:
# model = dict(
#     _scope_='mmrazor',
#     type='ItePruneAlgorithm',
#     architecture=dict(
#         type='ImageClassifier',
#         backbone=dict(
#             type='ResNet',
#             depth=34,
#             num_stages=4,
#             out_indices=(3, ),
#             style='pytorch'),
#         neck=dict(type='GlobalAveragePooling'),
#         head=dict(
#             type='LinearClsHead',
#             num_classes=1000,
#             in_channels=512,
#             loss=dict(type='CrossEntropyLoss', loss_weight=1.0),
#             topk=(1, 5)),
#         _scope_='mmcls',
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint=
#             'https://download.openmmlab.com/mmclassification/v0/resnet/resnet34_8xb32_in1k_20210831-f257d4e6.pth'
#         )),
#     mutator_cfg=dict(
#         type='ChannelMutator',
#         channel_unit_cfg=dict(
#             type='L1MutableChannelUnit',
#             default_args=dict(choice_mode='ratio'))),
#     target_pruning_ratio=dict({
#         'backbone.conv1_(0, 64)_64': 0.7,
#         'backbone.layer1.0.conv1_(0, 64)_64': 0.7,
#         'backbone.layer1.1.conv1_(0, 64)_64': 0.7,
#         'backbone.layer1.2.conv1_(0, 64)_64': 0.7,
#         'backbone.layer2.0.conv1_(0, 128)_128': 0.7,
#         'backbone.layer2.0.conv2_(0, 128)_128': 0.7,
#         'backbone.layer2.1.conv1_(0, 128)_128': 0.7,
#         'backbone.layer2.2.conv1_(0, 128)_128': 0.7,
#         'backbone.layer2.3.conv1_(0, 128)_128': 0.7,
#         'backbone.layer3.0.conv1_(0, 256)_256': 0.7,
#         'backbone.layer3.0.conv2_(0, 256)_256': 0.7,
#         'backbone.layer3.1.conv1_(0, 256)_256': 0.7,
#         'backbone.layer3.2.conv1_(0, 256)_256': 0.7,
#         'backbone.layer3.3.conv1_(0, 256)_256': 0.7,
#         'backbone.layer3.4.conv1_(0, 256)_256': 0.7,
#         'backbone.layer3.5.conv1_(0, 256)_256': 0.7,
#         'backbone.layer4.0.conv1_(0, 512)_512': 1.0,
#         'backbone.layer4.0.conv2_(0, 512)_512': 1.0,
#         'backbone.layer4.1.conv1_(0, 512)_512': 1.0,
#         'backbone.layer4.2.conv1_(0, 512)_512': 1.0
#     }),
#     step_epoch=1,
#     prune_times=1)
# dataset_type = 'ImageNet'
# data_preprocessor = dict(
#     mean=[123.675, 116.28, 103.53],
#     std=[58.395, 57.12, 57.375],
#     to_rgb=True,
#     type='mmcls.ClsDataPreprocessor')
# train_pipeline = [
#     dict(type='LoadImageFromFile', _scope_='mmcls'),
#     dict(type='RandomResizedCrop', scale=224, _scope_='mmcls'),
#     dict(type='RandomFlip', prob=0.5, direction='horizontal', _scope_='mmcls'),
#     dict(type='PackClsInputs', _scope_='mmcls')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile', _scope_='mmcls'),
#     dict(type='ResizeEdge', scale=256, edge='short', _scope_='mmcls'),
#     dict(type='CenterCrop', crop_size=224, _scope_='mmcls'),
#     dict(type='PackClsInputs', _scope_='mmcls')
# ]
# train_dataloader = dict(
#     batch_size=32,
#     num_workers=5,
#     dataset=dict(
#         type='ImageNet',
#         data_root='data/imagenet',
#         ann_file='meta/train.txt',
#         data_prefix='train',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='RandomResizedCrop', scale=224),
#             dict(type='RandomFlip', prob=0.5, direction='horizontal'),
#             dict(type='PackClsInputs')
#         ],
#         _scope_='mmcls'),
#     sampler=dict(type='DefaultSampler', shuffle=True, _scope_='mmcls'),
#     persistent_workers=True)
# val_dataloader = dict(
#     batch_size=32,
#     num_workers=5,
#     dataset=dict(
#         type='ImageNet',
#         data_root='data/imagenet',
#         ann_file='meta/val.txt',
#         data_prefix='val',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='ResizeEdge', scale=256, edge='short'),
#             dict(type='CenterCrop', crop_size=224),
#             dict(type='PackClsInputs')
#         ],
#         _scope_='mmcls'),
#     sampler=dict(type='DefaultSampler', shuffle=False, _scope_='mmcls'),
#     persistent_workers=True)
# val_evaluator = dict(type='Accuracy', topk=(1, 5), _scope_='mmcls')
# test_dataloader = dict(
#     batch_size=32,
#     num_workers=5,
#     dataset=dict(
#         type='ImageNet',
#         data_root='data/imagenet',
#         ann_file='meta/val.txt',
#         data_prefix='val',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='ResizeEdge', scale=256, edge='short'),
#             dict(type='CenterCrop', crop_size=224),
#             dict(type='PackClsInputs')
#         ],
#         _scope_='mmcls'),
#     sampler=dict(type='DefaultSampler', shuffle=False, _scope_='mmcls'),
#     persistent_workers=True)
# test_evaluator = dict(type='Accuracy', topk=(1, 5), _scope_='mmcls')
# optim_wrapper = dict(
#     optimizer=dict(
#         type='SGD', lr=0.1, momentum=0.9, weight_decay=0.0001,
#         _scope_='mmcls'))
# param_scheduler = dict(
#     type='MultiStepLR',
#     by_epoch=True,
#     milestones=[30, 60, 90],
#     gamma=0.1,
#     _scope_='mmcls')
# train_cfg = dict(by_epoch=True, max_epochs=100, val_interval=1)
# val_cfg = dict()
# test_cfg = dict()
# auto_scale_lr = dict(base_batch_size=256)
# default_scope = 'mmcls'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook', _scope_='mmcls'),
#     logger=dict(type='LoggerHook', interval=100, _scope_='mmcls'),
#     param_scheduler=dict(type='ParamSchedulerHook', _scope_='mmcls'),
#     checkpoint=dict(type='CheckpointHook', interval=1, _scope_='mmcls'),
#     sampler_seed=dict(type='DistSamplerSeedHook', _scope_='mmcls'),
#     visualization=dict(
#         type='VisualizationHook', enable=False, _scope_='mmcls'))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend', _scope_='mmcls')]
# visualizer = dict(
#     type='ClsVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     _scope_='mmcls')
# log_level = 'INFO'
# load_from = None
# resume = False
# architecture = dict(
#     type='ImageClassifier',
#     backbone=dict(
#         type='ResNet',
#         depth=34,
#         num_stages=4,
#         out_indices=(3, ),
#         style='pytorch'),
#     neck=dict(type='GlobalAveragePooling'),
#     head=dict(
#         type='LinearClsHead',
#         num_classes=1000,
#         in_channels=512,
#         loss=dict(type='CrossEntropyLoss', loss_weight=1.0),
#         topk=(1, 5)),
#     _scope_='mmcls',
#     init_cfg=dict(
#         type='Pretrained',
#         checkpoint=
#         'https://download.openmmlab.com/mmclassification/v0/resnet/resnet34_8xb32_in1k_20210831-f257d4e6.pth'
#     ))
# stage_ratio_1 = 0.7
# stage_ratio_2 = 0.7
# stage_ratio_3 = 0.7
# stage_ratio_4 = 1.0
# target_pruning_ratio = dict({
#     'backbone.conv1_(0, 64)_64': 0.7,
#     'backbone.layer1.0.conv1_(0, 64)_64': 0.7,
#     'backbone.layer1.1.conv1_(0, 64)_64': 0.7,
#     'backbone.layer1.2.conv1_(0, 64)_64': 0.7,
#     'backbone.layer2.0.conv1_(0, 128)_128': 0.7,
#     'backbone.layer2.0.conv2_(0, 128)_128': 0.7,
#     'backbone.layer2.1.conv1_(0, 128)_128': 0.7,
#     'backbone.layer2.2.conv1_(0, 128)_128': 0.7,
#     'backbone.layer2.3.conv1_(0, 128)_128': 0.7,
#     'backbone.layer3.0.conv1_(0, 256)_256': 0.7,
#     'backbone.layer3.0.conv2_(0, 256)_256': 0.7,
#     'backbone.layer3.1.conv1_(0, 256)_256': 0.7,
#     'backbone.layer3.2.conv1_(0, 256)_256': 0.7,
#     'backbone.layer3.3.conv1_(0, 256)_256': 0.7,
#     'backbone.layer3.4.conv1_(0, 256)_256': 0.7,
#     'backbone.layer3.5.conv1_(0, 256)_256': 0.7,
#     'backbone.layer4.0.conv1_(0, 512)_512': 1.0,
#     'backbone.layer4.0.conv2_(0, 512)_512': 1.0,
#     'backbone.layer4.1.conv1_(0, 512)_512': 1.0,
#     'backbone.layer4.2.conv1_(0, 512)_512': 1.0
# })
# launcher = 'none'
# work_dir = './work_dirs/prune_resnet34'
#
# Result has been saved to /home/liukai/Documents/mmlab2/mmrazor_github2/work_dirs/prune_resnet34/modules_statistic_results.json
# 11/02 17:45:21 - mmengine - WARNING - add a input before backbone.conv1(backbone.conv1), error: backbone.conv1(backbone.conv1)
# 11/02 17:45:21 - mmengine - WARNING - add a output after head.fc(head.fc), error: head.fc(head.fc)
# 11/02 17:45:22 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 11/02 17:45:24 - mmengine - INFO - load model from: https://download.openmmlab.com/mmclassification/v0/resnet/resnet34_8xb32_in1k_20210831-f257d4e6.pth
# 11/02 17:45:24 - mmengine - INFO - http loads checkpoint from path: https://download.openmmlab.com/mmclassification/v0/resnet/resnet34_8xb32_in1k_20210831-f257d4e6.pth
# 11/02 17:45:24 - mmengine - INFO - Checkpoints will be saved to /home/liukai/Documents/mmlab2/mmrazor_github2/work_dirs/prune_resnet34 by HardDiskBackend.
# 11/02 17:45:24 - mmengine - INFO - The model is pruned at 0th epoch once.
# 11/02 17:45:25 - mmengine - INFO - Exp name: prune_resnet34_20221102_174520
# 11/02 17:45:25 - mmengine - INFO - Saving checkpoint at 1 epochs
# 11/02 17:45:26 - mmengine - INFO - The model is pruned at 0th epoch once.
# 11/02 17:45:26 - mmengine - INFO - Epoch(val) [1][1/1]  accuracy/top1: 0.0000  accuracy/top5: 5.0000
# 11/02 17:45:27 - mmengine - INFO - Exp name: prune_resnet34_20221102_174520
# 11/02 17:45:27 - mmengine - INFO - Saving checkpoint at 2 epochs
# 11/02 17:45:28 - mmengine - INFO - Epoch(val) [2][1/1]  accuracy/top1: 0.0000  accuracy/top5: 0.0000
# 11/02 17:45:28 - mmengine - INFO - Exp name: prune_resnet34_20221102_174520
# 11/02 17:45:28 - mmengine - INFO - Saving checkpoint at 3 epochs
# 11/02 17:45:29 - mmengine - INFO - Epoch(val) [3][1/1]  accuracy/top1: 0.0000  accuracy/top5: 0.0000
# 11/02 17:45:30 - mmengine - INFO - Exp name: prune_resnet34_20221102_174520
# 11/02 17:45:30 - mmengine - INFO - Saving checkpoint at 4 epochs
# 11/02 17:45:31 - mmengine - INFO - Epoch(val) [4][1/1]  accuracy/top1: 0.0000  accuracy/top5: 0.0000
# 11/02 17:45:31 - mmengine - INFO - Exp name: prune_resnet34_20221102_174520
# 11/02 17:45:31 - mmengine - INFO - Saving checkpoint at 5 epochs
# 11/02 17:45:32 - mmengine - INFO - Epoch(val) [5][1/1]  accuracy/top1: 0.0000  accuracy/top5: 0.0000
# 11/02 17:45:32 - mmengine - INFO - Exp name: prune_resnet34_20221102_174520
# 11/02 17:45:32 - mmengine - INFO - Saving checkpoint at 6 epochs
# 11/02 17:45:34 - mmengine - INFO - Epoch(val) [6][1/1]  accuracy/top1: 0.0000  accuracy/top5: 0.0000
# 11/02 17:45:34 - mmengine - INFO - Exp name: prune_resnet34_20221102_174520
# 11/02 17:45:34 - mmengine - INFO - Saving checkpoint at 7 epochs
# 11/02 17:45:35 - mmengine - INFO - Epoch(val) [7][1/1]  accuracy/top1: 0.0000  accuracy/top5: 0.0000
# 11/02 17:45:35 - mmengine - INFO - Exp name: prune_resnet34_20221102_174520
# 11/02 17:45:35 - mmengine - INFO - Saving checkpoint at 8 epochs
# 11/02 17:45:37 - mmengine - INFO - Epoch(val) [8][1/1]  accuracy/top1: 0.0000  accuracy/top5: 0.0000
# 11/02 17:45:37 - mmengine - INFO - Exp name: prune_resnet34_20221102_174520
# 11/02 17:45:37 - mmengine - INFO - Saving checkpoint at 9 epochs
# 11/02 17:45:38 - mmengine - INFO - Epoch(val) [9][1/1]  accuracy/top1: 0.0000  accuracy/top5: 0.0000
# 11/02 17:45:38 - mmengine - INFO - Exp name: prune_resnet34_20221102_174520
# 11/02 17:45:38 - mmengine - INFO - Saving checkpoint at 10 epochs
# 11/02 17:45:39 - mmengine - INFO - Epoch(val) [10][1/1]  accuracy/top1: 0.0000  accuracy/top5: 0.0000
# 11/02 17:45:40 - mmengine - INFO - Exp name: prune_resnet34_20221102_174520
# 11/02 17:45:40 - mmengine - INFO - Saving checkpoint at 11 epochs
# 11/02 17:45:41 - mmengine - INFO - Epoch(val) [11][1/1]  accuracy/top1: 0.0000  accuracy/top5: 0.0000
# 11/02 17:45:41 - mmengine - INFO - Exp name: prune_resnet34_20221102_174520
# 11/02 17:45:41 - mmengine - INFO - Saving checkpoint at 12 epochs
# 11/02 17:45:42 - mmengine - INFO - Epoch(val) [12][1/1]  accuracy/top1: 0.0000  accuracy/top5: 0.0000
# 11/02 17:45:42 - mmengine - INFO - Exp name: prune_resnet34_20221102_174520
# 11/02 17:45:42 - mmengine - INFO - Saving checkpoint at 13 epochs
# 11/02 17:45:43 - mmengine - INFO - Epoch(val) [13][1/1]  accuracy/top1: 0.0000  accuracy/top5: 0.0000
# 11/02 17:45:43 - mmengine - INFO - Exp name: prune_resnet34_20221102_174520
# 11/02 17:45:43 - mmengine - INFO - Saving checkpoint at 14 epochs
# 11/02 17:45:44 - mmengine - INFO - Epoch(val) [14][1/1]  accuracy/top1: 0.0000  accuracy/top5: 0.0000
# 11/02 17:45:45 - mmengine - INFO - Exp name: prune_resnet34_20221102_174520
# 11/02 17:45:45 - mmengine - INFO - Saving checkpoint at 15 epochs
# 11/02 17:45:46 - mmengine - INFO - Epoch(val) [15][1/1]  accuracy/top1: 0.0000  accuracy/top5: 0.0000
# 11/02 17:45:46 - mmengine - INFO - Exp name: prune_resnet34_20221102_174520
# 11/02 17:45:46 - mmengine - INFO - Saving checkpoint at 16 epochs
# 11/02 17:45:47 - mmengine - INFO - Epoch(val) [16][1/1]  accuracy/top1: 0.0000  accuracy/top5: 0.0000
# 11/02 17:45:47 - mmengine - INFO - Exp name: prune_resnet34_20221102_174520
# 11/02 17:45:47 - mmengine - INFO - Saving checkpoint at 17 epochs
# 11/02 17:45:48 - mmengine - INFO - Epoch(val) [17][1/1]  accuracy/top1: 0.0000  accuracy/top5: 0.0000
# 11/02 17:45:48 - mmengine - INFO - Exp name: prune_resnet34_20221102_174520
# 11/02 17:45:48 - mmengine - INFO - Saving checkpoint at 18 epochs
# 11/02 17:45:49 - mmengine - INFO - Epoch(val) [18][1/1]  accuracy/top1: 0.0000  accuracy/top5: 0.0000
# 11/02 17:45:50 - mmengine - INFO - Exp name: prune_resnet34_20221102_174520
# 11/02 17:45:50 - mmengine - INFO - Saving checkpoint at 19 epochs
# 11/02 17:45:51 - mmengine - INFO - Epoch(val) [19][1/1]  accuracy/top1: 0.0000  accuracy/top5: 0.0000
# 11/02 17:45:51 - mmengine - INFO - Exp name: prune_resnet34_20221102_174520
# 11/02 17:45:51 - mmengine - INFO - Saving checkpoint at 20 epochs
# 11/02 17:45:52 - mmengine - INFO - Epoch(val) [20][1/1]  accuracy/top1: 0.0000  accuracy/top5: 0.0000
# 11/02 17:45:52 - mmengine - INFO - Exp name: prune_resnet34_20221102_174520
# 11/02 17:45:52 - mmengine - INFO - Saving checkpoint at 21 epochs
# 11/02 17:45:53 - mmengine - INFO - Epoch(val) [21][1/1]  accuracy/top1: 0.0000  accuracy/top5: 0.0000
# 11/02 17:45:53 - mmengine - INFO - Exp name: prune_resnet34_20221102_174520
# 11/02 17:45:53 - mmengine - INFO - Saving checkpoint at 22 epochs
# 11/02 17:45:54 - mmengine - INFO - Epoch(val) [22][1/1]  accuracy/top1: 0.0000  accuracy/top5: 0.0000
# 11/02 17:45:55 - mmengine - INFO - Exp name: prune_resnet34_20221102_174520
# 11/02 17:45:55 - mmengine - INFO - Saving checkpoint at 23 epochs
# 11/02 17:45:56 - mmengine - INFO - Epoch(val) [23][1/1]  accuracy/top1: 0.0000  accuracy/top5: 0.0000
# 11/02 17:45:56 - mmengine - INFO - Exp name: prune_resnet34_20221102_174520
# 11/02 17:45:56 - mmengine - INFO - Saving checkpoint at 24 epochs
# 11/02 17:45:57 - mmengine - INFO - Epoch(val) [24][1/1]  accuracy/top1: 0.0000  accuracy/top5: 0.0000
# 11/02 17:45:57 - mmengine - INFO - Exp name: prune_resnet34_20221102_174520
# 11/02 17:45:57 - mmengine - INFO - Saving checkpoint at 25 epochs
# 11/02 17:45:58 - mmengine - INFO - Epoch(val) [25][1/1]  accuracy/top1: 0.0000  accuracy/top5: 0.0000
# 11/02 17:45:58 - mmengine - INFO - Exp name: prune_resnet34_20221102_174520
# 11/02 17:45:58 - mmengine - INFO - Saving checkpoint at 26 epochs
# 11/02 17:45:59 - mmengine - INFO - Epoch(val) [26][1/1]  accuracy/top1: 0.0000  accuracy/top5: 0.0000
# 11/02 17:46:00 - mmengine - INFO - Exp name: prune_resnet34_20221102_174520
# 11/02 17:46:00 - mmengine - INFO - Saving checkpoint at 27 epochs
# ^C
# Traceback (most recent call last):
#   File "/home/liukai/Documents/mmlab2/mmrazor_github2/./tools/train.py", line 110, in <module>
#     main()
#   File "/home/liukai/Documents/mmlab2/mmrazor_github2/./tools/train.py", line 106, in main
#     runner.train()
#   File "/home/liukai/Documents/mmlab2/others/max/mmengine/mmengine/runner/runner.py", line 1631, in train
#     model = self.train_loop.run()  # type: ignore
#   File "/home/liukai/Documents/mmlab2/others/max/mmengine/mmengine/runner/loops.py", line 88, in run
#     self.run_epoch()
#   File "/home/liukai/Documents/mmlab2/others/max/mmengine/mmengine/runner/loops.py", line 106, in run_epoch
#     self.runner.call_hook('after_train_epoch')
#   File "/home/liukai/Documents/mmlab2/others/max/mmengine/mmengine/runner/runner.py", line 1693, in call_hook
#     getattr(hook, fn_name)(self, **kwargs)
#   File "/home/liukai/Documents/mmlab2/others/max/mmengine/mmengine/hooks/checkpoint_hook.py", line 247, in after_train_epoch
#     self._save_checkpoint(runner)
#   File "/home/liukai/Documents/mmlab2/others/max/mmengine/mmengine/dist/utils.py", line 329, in wrapper
#     return func(*args, **kwargs)
#   File "/home/liukai/Documents/mmlab2/others/max/mmengine/mmengine/hooks/checkpoint_hook.py", line 286, in _save_checkpoint
#     runner.save_checkpoint(
#   File "/home/liukai/Documents/mmlab2/others/max/mmengine/mmengine/dist/utils.py", line 329, in wrapper
#     return func(*args, **kwargs)
#   File "/home/liukai/Documents/mmlab2/others/max/mmengine/mmengine/runner/runner.py", line 2092, in save_checkpoint
#     save_checkpoint(checkpoint, filepath)
#   File "/home/liukai/Documents/mmlab2/others/max/mmengine/mmengine/runner/checkpoint.py", line 698, in save_checkpoint
#     file_client.put(f.getvalue(), filename)
# KeyboardInterrupt

# %%
# 清理临时文件
# ! rm prune_ratio_templace.json
